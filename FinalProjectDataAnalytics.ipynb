# %% [markdown]
# <a href="https://colab.research.google.com/github/mesaayu/CapstoneProjectDataAnalytics/blob/main/FinalProjectDataAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_netflix = pd.read_csv('/content/netflix_titles.csv')
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
scoped =  ['type', 'title', 'release_year', 'listed_in', 'country']

df_terpilih = df_netflix[scoped]

df_terpilih_filtered = df_terpilih[df_terpilih['release_year'].between(2017, 2021)]

df_terpilih_filtered.head(11)
# Out:
#        type                                title  release_year  \
# 0     Movie                 Dick Johnson Is Dead          2020
# 1   TV Show                        Blood & Water          2021
# 2   TV Show                            Ganglands          2021
# 3   TV Show                Jailbirds New Orleans          2021
# 4   TV Show                         Kota Factory          2021
# 5   TV Show                        Midnight Mass          2021
# 6     Movie     My Little Pony: A New Generation          2021
# 8   TV Show        The Great British Baking Show          2021
# 9     Movie                         The Starling          2021
# 10  TV Show  Vendetta: Truth, Lies and The Mafia          2021
# 11  TV Show                     Bangkok Breaking          2021
#
#                                             listed_in         country
# 0                                       Documentaries   United States
# ...

# %%
modusCountry =  df_terpilih_filtered['country'].mode()[0]

modusCountry
# Out:
# 'United States'

# %%
df_terpilih_filtered['country'] = df_terpilih_filtered['country'].fillna(modusCountry)
# Out:
# <ipython-input-7-86a57411ef49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_terpilih_filtered['country'] = df_terpilih_filtered['country'].fillna(modusCountry)

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_terpilih_filtered['country'].isnull().sum()
# Out:
# 0

# %%
df_terpilih_filtered
# Out:
#          type                      title  release_year  \
# 0       Movie       Dick Johnson Is Dead          2020
# 1     TV Show              Blood & Water          2021
# 2     TV Show                  Ganglands          2021
# 3     TV Show      Jailbirds New Orleans          2021
# 4     TV Show               Kota Factory          2021
# ...       ...                        ...           ...
# 8774    Movie                  يوم الدين          2018
# 8775  TV Show            Yeh Meri Family          2018
# 8786    Movie               You Can Tutu          2017
# 8787    Movie  You Can’t Fight Christmas          2017
# 8803  TV Show                Zombie Dumb          2018
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# ...

# %%
df_terpilih_filtered.describe()
# Out:
#        release_year
# count   4754.000000
# mean    2018.774085
# std        1.325705
# min     2017.000000
# 25%     2018.000000
# 50%     2019.000000
# 75%     2020.000000
# max     2021.000000

# %%
df_terpilih_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4754 entries, 0 to 8803
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4754 non-null   object
#  1   title         4754 non-null   object
#  2   release_year  4754 non-null   int64
#  3   listed_in     4754 non-null   object
#  4   country       4754 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 222.8+ KB

# %%
# Identifikasi nilai null di setiap kolom
nilai_null = df_terpilih_filtered.isnull()

jumlah_null_per_kolom = nilai_null.sum()

jumlah_null_per_kolom
# Out:
# type            0
# title           0
# release_year    0
# listed_in       0
# country         0
# dtype: int64

# %%
duplikat = df_terpilih_filtered.duplicated()

print("Data Asli:")
print(df_terpilih_filtered)

print("\nIdentifikasi Data Duplikat:")
duplikat.sum()
# Out:
# Data Asli:
#          type                      title  release_year  \
# 0       Movie       Dick Johnson Is Dead          2020
# 1     TV Show              Blood & Water          2021
# 2     TV Show                  Ganglands          2021
# 3     TV Show      Jailbirds New Orleans          2021
# 4     TV Show               Kota Factory          2021
# ...       ...                        ...           ...
# 8774    Movie                  يوم الدين          2018
# 8775  TV Show            Yeh Meri Family          2018
# 8786    Movie               You Can Tutu          2017
# 8787    Movie  You Can’t Fight Christmas          2017
# 8803  TV Show                Zombie Dumb          2018
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# ...

# %%
panjang_tidak_sesuai = df_terpilih_filtered[df_terpilih_filtered['release_year'].apply(lambda x: len(str(x)) != 4)]

print("Panjang yang tidak sesuai:")
print(panjang_tidak_sesuai)
# Out:
# Panjang yang tidak sesuai:
# Empty DataFrame
# Columns: [type, title, release_year, listed_in, country]
# Index: []

# %%
df_terpilih_filtered
# Out:
#          type                      title  release_year  \
# 0       Movie       Dick Johnson Is Dead          2020
# 1     TV Show              Blood & Water          2021
# 2     TV Show                  Ganglands          2021
# 3     TV Show      Jailbirds New Orleans          2021
# 4     TV Show               Kota Factory          2021
# ...       ...                        ...           ...
# 8774    Movie                  يوم الدين          2018
# 8775  TV Show            Yeh Meri Family          2018
# 8786    Movie               You Can Tutu          2017
# 8787    Movie  You Can’t Fight Christmas          2017
# 8803  TV Show                Zombie Dumb          2018
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# ...

# %%
find_modus = df_terpilih_filtered['listed_in'].mode()[0]

find_modus
# Out:
# 'Documentaries'

# %%
modus_per_year = df_terpilih_filtered.groupby('release_year')['listed_in'].apply(lambda x: x.mode().value_counts().idxmax())

jumlah_modus_per_year = df_terpilih_filtered.groupby(['release_year', 'listed_in'])['listed_in'].count().groupby('release_year').max()

print("Nilai Modus (Genre Terbanyak) untuk Setiap Tahun:")
print(modus_per_year)
print("\nJumlah Setiap Nilai Modus per Tahun:")
print(jumlah_modus_per_year)
# Out:
# Nilai Modus (Genre Terbanyak) untuk Setiap Tahun:
# release_year
# 2017                   Documentaries
# 2018                 Stand-Up Comedy
# 2019                 Stand-Up Comedy
# 2020    Dramas, International Movies
# 2021                        Kids' TV
# Name: listed_in, dtype: object
#
# Jumlah Setiap Nilai Modus per Tahun:
# release_year
# 2017    89
# 2018    58
# 2019    48
# 2020    42
# 2021    24
# Name: listed_in, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
modus_per_year = df_terpilih_filtered.groupby('release_year')['listed_in'].apply(lambda x: x.mode().value_counts().idxmax())

jumlah_modus_per_year = df_terpilih_filtered.groupby(['release_year', 'listed_in'])['listed_in'].count().groupby('release_year').max()

x_positions = range(len(modus_per_year))

plt.figure(figsize=(14, 8))

bars = plt.bar(x_positions, jumlah_modus_per_year, align='center', color='#2A9D8F')

for i, genre in enumerate(modus_per_year):
    plt.text(bars[i].get_x() + bars[i].get_width() / 2.0, bars[i].get_height(), genre, ha='center', va='bottom')

for i, jumlah in enumerate(jumlah_modus_per_year):
    plt.text(bars[i].get_x() + bars[i].get_width() / 2.0, bars[i].get_height() + 3, str(jumlah), ha='center')

plt.xlabel('Tahun Rilis')
plt.ylabel('Jumlah Perilisan')
plt.title('Genre Terbanyak per Tahun dan Jumlahnya')
plt.xticks(x_positions, modus_per_year.index)
plt.tight_layout()
plt.show()

# %%
colors = ['#264653', '#2A9D8F']

plt.figure(figsize=(12, 8))

plt.plot(documentaries_per_year.index, documentaries_per_year.values, marker='o', linestyle='-', color=colors[1])

plt.xlabel('Tahun Rilis')
plt.ylabel('Jumlah Film Documentaries')
plt.title('Jumlah Film Genre Documentaries per Tahun')
plt.grid(True)
plt.show()

# %%
documentaries_per_year = documentaries_data.groupby('release_year').size()

print("Jumlah Film 'Documentaries' per Tahun:")
print(documentaries_per_year)
# Out:
# Jumlah Film 'Documentaries' per Tahun:
# release_year
# 2017    89
# 2018    54
# 2019    33
# 2020    23
# 2021    20
# dtype: int64

# %%
filtered_data_2020_2021 = df_terpilih_filtered[(df_terpilih_filtered['release_year'] >= 2020) & (df_terpilih_filtered['release_year'] <= 2021)]

modus_2020_2021 = filtered_data_2020_2021['listed_in'].mode()[0]

print("Modus (Genre Terbanyak) untuk Tahun 2020-2021:")
print(modus_2020_2021)
# Out:
# Modus (Genre Terbanyak) untuk Tahun 2020-2021:
# Stand-Up Comedy

# %%
genre_counts_2020_2021 = filtered_data_2020_2021['listed_in'].value_counts()

dua_genre_terbanyak = genre_counts_2020_2021.head(5)

print("Dua Genre Terbanyak untuk Tahun 2020-2021:")
print(dua_genre_terbanyak)
# Out:
# Dua Genre Terbanyak untuk Tahun 2020-2021:
# Stand-Up Comedy                 53
# Dramas, International Movies    52
# Kids' TV                        46
# Children & Family Movies        46
# Documentaries                   43
# Name: listed_in, dtype: int64

# %%
labels = dua_genre_terbanyak.index
sizes = dua_genre_terbanyak.values

colors = ['#264653', '#2A9D8F', '#E9C46A', '#F4A261', '#E76F51']

plt.figure(figsize=(10, 6))

labels_with_counts = [f'{label} ({size})' for label, size in zip(labels, sizes)]

explode = (0.1, 0.1, 0, 0, 0)

plt.pie(sizes, labels=labels_with_counts, autopct='%1.1f%%', colors=colors, explode=explode)
plt.title('Persentase Dua Genre Terbanyak Tahun 2020-2021')

plt.show()

# %%
df_terpilih_filtered['listed_in'].nunique()
# Out:
# 401

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
genre_counts = df_terpilih_filtered['listed_in'].value_counts()

# %%
genre_counts
# Out:
# Documentaries                                               219
# Stand-Up Comedy                                             216
# Dramas, International Movies                                169
# Dramas, Independent Movies, International Movies            139
# Kids' TV                                                    129
#                                                            ...
# Dramas, Music & Musicals, Romantic Movies                     1
# International TV Shows, TV Action & Adventure, TV Horror      1
# Action & Adventure, Comedies, Romantic Movies                 1
# International TV Shows, Korean TV Shows, TV Horror            1
# Action & Adventure, Documentaries, Sports Movies              1
# Name: listed_in, Length: 401, dtype: int64

# %%
colors = ['#264653', '#2A9D8F', '#E9C46A', '#F4A261', '#E76F51']

min_genres = genre_counts.tail(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=min_genres.values, y=min_genres.index, palette=colors)
plt.xlabel('Jumlah')
plt.ylabel('Jenis Film')
plt.title('10 Jenis Film Terbawah')
plt.show()

# %%
type_counts = df_terpilih_filtered['type'].value_counts()

# %%
type_counts
# Out:
# Movie      2961
# TV Show    1793
# Name: type, dtype: int64

# %%
colors = ['#264653', '#2A9D8F', '#E9C46A', '#F4A261', '#E76F51']

top_genres = genre_counts.head(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_genres.values, y=top_genres.index, palette=colors)
plt.xlabel('Jumlah')
plt.ylabel('Jenis Film')
plt.title('10 Jenis Film Terbanyak')
plt.show()

# %%
colors = ['#264653', '#2A9D8F']

genre_per_year = df_terpilih_filtered.groupby(['release_year', 'type']).size().unstack()

plt.figure(figsize=(14, 8))
genre_per_year.plot(kind='bar', stacked=True, color=colors)
plt.xlabel('Tahun Rilis')
plt.ylabel('Jumlah')
plt.title('Jumlah Jenis Film per Tahun')
plt.legend(title='Jenis Film', labels=['Movie', 'TV Show'])
plt.show()

# %%
colors = ['#264653', '#2A9D8F']

plt.figure(figsize=(14, 8))
plt.bar(genre_per_year.index, genre_per_year['Movie'], width=0.4, label='Movie', color=colors[0])
plt.bar(genre_per_year.index + 0.4, genre_per_year['TV Show'], width=0.4, label='TV Show', color=colors[1])

plt.xlabel('Tahun Rilis')
plt.ylabel('Jumlah')
plt.title('Jumlah Jenis Film per Tahun')
plt.legend(title='Jenis Film')
plt.show()

# %%
df_terpilih_filtered.to_csv('cleaning.csv')
